# %%
import mwpf
mwpf.Visualizer.embed()
# Out:
# <div><span style="color: white; font-size: 8px; padding: 4px; background-color: rgba(36, 110, 36); border-radius: 4px;">MWPF visualization library embedded (378kB)</span></div><script type="module" id='hyperion_visual_compressed_js_caller'>
# /* HYPERION_VISUAL_MODULE_CODE_BEGIN */
# const module_base64 =
# /* HYPERION_VISUAL_GZIP_B64_BEGIN */
# "..."
# /* HYPERION_VISUAL_GZIP_B64_END */
# function uint8_to_array_buffer(array) {
#     return array.buffer.slice(array.byteOffset, array.byteLength + array.byteOffset)
# }
# function base64_to_array_buffer(base64_str) {
#     return uint8_to_array_buffer(Uint8Array.from(atob(base64_str), c => c.charCodeAt(0)))
# }
# async function decompress_content(base64_str) {
#     const base64_binary = base64_to_array_buffer(base64_str)
#     const blob = new Blob([base64_binary])
#     const decompressed_stream = blob.stream()
#         .pipeThrough(new DecompressionStream('gzip'))
#     const decompressed = await new Response(decompressed_stream).arrayBuffer()
#     return decompressed
# }
# async function load_module() {
#     const decompressed = await decompress_content(module_base64)
#     const text_decoder = new TextDecoder("utf-8")
#     let module_code = text_decoder.decode(decompressed)
#     ;module_code = module_code.replaceAll('window.hyperion_visual', 'window.hyperion_visual_2024_11_14_22_37_23');/* HYPERION_VISUAL_MODULE_CODE_DECODED */
#     // add script to html root
#     if (window.hyperion_visual_2024_11_14_22_37_23 != undefined) {
#         console.warn("window.hyperion_visual_2024_11_14_22_37_23 already loaded; skip loading")
#     } else {
#         console.log("window.hyperion_visual_2024_11_14_22_37_23 not loaded; loading")
#         const script = document.createElement('script')
#         script.type = "module"
#         script.innerHTML = module_code
#         document.body.appendChild(script)
#     }
# }
# load_module()
# /* HYPERION_VISUAL_MODULE_CODE_END */
# </script>

# %% [markdown]
# # Parity Matrix Tutorial

# %% [markdown]
# We define Parity Matrix in our paper, which represents the complete parity check constraints over some vertices $V_M$ and edges $E_M$.
# The solution space of parity factor is written as $\vec{x} = \{x_e | e \in E_M\} \subseteq \mathbb{Z}_2^{|E_M|}$ and each edge has a binary variable $x_e \in \{ 0, 1 \}$ representing the edge in the parity factor solution or not.
# There is one parity constraint associated with each vertex, namely $\sum_{e \in E_M | v \in e} x_e = \begin{cases}1, & v\in D\\0, & v \notin D\end{cases}\mod 2$ where $D$ is the set of defect vertices that indicates an odd number of errors (edges) have flipped it.

# %% [markdown]
# In order to provide the functionality required for this project, the Rust implementation of the Parity Matrix is a nested Generic implementation.
# - `BasicMatrix`: the basic parity matrix
# - `TightMatrix = Tight<BasicMatrix>`: adding the ability to hide loose edges and only show tight edges in the matrix
# - `TailMatrix = Tail<TightMatrix>`: adding the ability to reorder columns of the parity matrix
# - `EchelonMatrix = Echelon<TailMatrix>`: adding the ability to calculate the reduced row echelon form
#
# Each of them can be converted to another (a new object) via `get_base(self)` and `ClassName(base)` functions.
# For example, given a basic matrix `basic_matrix`, we can construct a new tight matrix by `tight_matrix = TightMatrix(basic_matrix)`.
# We can go back to the basic matrix with `basic_matrix_2 = tight_matrix.get_base()`, which returns a new matrix.
# One can also convert the class explicitly through multiple levels, for example, `BasicMatrix(echelon_matrix)` and `EchelonMatrix(basic_matrix)` are all valid constructions.
#
# In the following sections, we'll go through the capabilities of individual matrices.

# %% [markdown]
# ## BasicMatrix
#
# We first look at a very simple parity matrix implementation that offers full customization of columns and rows.
#
# The matrix has the following APIs:
# - `add_variable(self, edge_index: int) -> int | None`: return the variable index (column index) in the matrix if added; otherwise if the edge already exists in the matrix, return `None`. User can use `edge_to_var_index` below to get the variable index instead.
# - `add_constraint(self, vertex_index: int, incident_edges: list[int], parity: bool) -> list[int] | None`: add a row in the parity matrix with the vertex. If the vertex constraint has already been added, return `None` (to avoid duplicate rows). User don't have to add all the variables before they add a constraint. All the missing variables (columns) will be automaticall added. It will return a list of variable indices of newly added edges.
# - `get_lhs(self, row: int, var_index: int) -> bool`: get left-hand side value
# - `get_rhs(self, row: int) -> bool`: get right-hand side value
# - `var_to_edge_index(self, var_index: int) -> int`
# - `edge_to_var_index(self, edge_index: int) -> int`
# - `exists_edge(self, edge_index: int) -> bool`
# - `get_vertices(self) -> set[int]`
#
# The following APIs are for matrix view. For `BasicMatrix`, the visible matrix when you call `matrix.show()` or `print(matrix)` is exactly the original parity matrix. For more complicated matricies, the columns or the rows might change.
# - `columns: int`: property, the number of columns in the visual view; For `BasicMatrix`, column index is the variable index; for more complicated matrices that supports hiding some variables (`TightMatrix`) or reorder the variables (`TailMatrix`), the visual column index does not immediately corresponds to variable index, and the following functions provide the translation.
# - `column_to_var_index(self, column: int) -> int`
# - `column_to_edge_index(self, column: int) -> int`
# - `get_view_edges(self) -> list[int]`: return the edge indices of the visble columns
# - `var_to_column_index(self, var_index: int) -> int | None`: return the column index if the variable is visible, otherwise return `None`
# - `edge_to_column_index(self, edge_index: int) -> int | None`: return the column index if the edge is visible, otherwise return `None`
# - `rows: int`: property, the number of rows in the visual view; For `BasicMatrix`, the number of vertices is the number of rows; for more complicated matrices that supports hiding zero rows (`EchelonMatrix`), the number of rows may be less than the number of vertices.

# %%
matrix = mwpf.BasicMatrix()
print(matrix)  # you can print in the text form
matrix.show()  # or with a better HTML form with colors and highlights
# Out:
# ┌┬───┐
# ┊┊ = ┊
# ╞╪═══╡
# └┴───┘
# <div id="RDHQOHAOMLHYZSUL" style="font-family: monospace; white-space: pre;">┌┬───┐
# ┊┊ = ┊
# ╞╪═══╡
# └┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[],"table":[[""," = "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("RDHQOHAOMLHYZSUL");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('RDHQOHAOMLHYZSUL');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#RDHQOHAOMLHYZSUL", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('RDHQOHAOMLHYZSUL');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# Then we can add some variables to the matrix. Each variable corresponds to a column in the parity matrix.

# %%
matrix.add_variable(edge_index=1)
matrix.add_variable(12)
matrix.add_variable(4)
matrix.add_variable(345)
matrix.show()
# Out:
# <div id="NEGOCONXJJICHSIW" style="font-family: monospace; white-space: pre;">┌┬─┬─┬─┬─┬───┐
# ┊┊1┊1┊4┊3┊ = ┊
# ┊┊ ┊2┊ ┊4┊   ┊
# ┊┊ ┊ ┊ ┊5┊   ┊
# ╞╪═╪═╪═╪═╪═══╡
# └┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[1,12,4,345],"table":[["","1","1\n2","4","3\n4\n5"," = "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("NEGOCONXJJICHSIW");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('NEGOCONXJJICHSIW');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#NEGOCONXJJICHSIW", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('NEGOCONXJJICHSIW');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# We can then add some constraint. Each constraint is a row in the parity matrix, corresponding to a vertex?

# %%
matrix.add_constraint(0, [1, 4, 12], True)
matrix.add_constraint(3, [4, 345], False)
matrix.add_constraint(4, [1, 345], True)
matrix.show()
# Out:
# <div id="UDNRUXPLKQZQZBBW" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊1┊1┊4┊3┊ = ┊
# ┊ ┊ ┊2┊ ┊4┊   ┊
# ┊ ┊ ┊ ┊ ┊5┊   ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊1┊1┊ ┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊ ┊ ┊1┊1┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊1┊ ┊ ┊1┊ 1 ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[1,12,4,345],"table":[["","1","1\n2","4","3\n4\n5"," = "],["0","1","1","1"," "," 1 "],["1"," "," ","1","1","   "],["2","1"," "," ","1"," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("UDNRUXPLKQZQZBBW");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('UDNRUXPLKQZQZBBW');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#UDNRUXPLKQZQZBBW", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('UDNRUXPLKQZQZBBW');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# We can do row operations on this matrix: `xor_row` and `swap_row`. The arguments are the indices of the rows.

# %%
matrix.xor_row(target=2, source=0)
matrix.show()
# Out:
# <div id="XWWUOMXRXBIYTYZC" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊1┊1┊4┊3┊ = ┊
# ┊ ┊ ┊2┊ ┊4┊   ┊
# ┊ ┊ ┊ ┊ ┊5┊   ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊1┊1┊ ┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊ ┊ ┊1┊1┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊ ┊1┊1┊1┊   ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[1,12,4,345],"table":[["","1","1\n2","4","3\n4\n5"," = "],["0","1","1","1"," "," 1 "],["1"," "," ","1","1","   "],["2"," ","1","1","1","   "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("XWWUOMXRXBIYTYZC");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('XWWUOMXRXBIYTYZC');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#XWWUOMXRXBIYTYZC", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('XWWUOMXRXBIYTYZC');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# We can do a sequence of operations, which gives us a reduced row Echelon form matrix.

# %%
matrix.swap_row(1, 2)
matrix.xor_row(0, 1)
matrix.xor_row(1, 2)
matrix.show()
# Out:
# <div id="AZMTWXKFBIAHWQLI" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊1┊1┊4┊3┊ = ┊
# ┊ ┊ ┊2┊ ┊4┊   ┊
# ┊ ┊ ┊ ┊ ┊5┊   ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊ ┊ ┊1┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊ ┊1┊ ┊ ┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊ ┊ ┊1┊1┊   ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[1,12,4,345],"table":[["","1","1\n2","4","3\n4\n5"," = "],["0","1"," "," ","1"," 1 "],["1"," ","1"," "," ","   "],["2"," "," ","1","1","   "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("AZMTWXKFBIAHWQLI");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('AZMTWXKFBIAHWQLI');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#AZMTWXKFBIAHWQLI", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('AZMTWXKFBIAHWQLI');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# ## TightMatrix
#
# In the above `BasicMatrix`, we consider all edges as columns.
# However, often times we add an edge but will not select it (force $x_e = 0$).
# For example, in MWPF decoder, we use the complementary slackness theorem to infer which edges can be selected in the optimal MWPF solution.
# The theorem says $$\sum_{S\in\mathcal{O}|e \in \delta(S)} y_S < w_e \Longrightarrow x_e = 0$$, i.e., only tight edges ($\sum_{S\in\mathcal{O}|e \in \delta(S)} y_S = w_e$) can be possibly chosen ($x_e \in \{0,1\}$), loose edges ($\sum_{S\in\mathcal{O}|e \in \delta(S)} y_S < w_e$) will never be choosen ($x_e = 0$).
#
# We want the matrix to only contain columns that corresponds to tight edges, while still maintains those loose edges just in case they become tight in the future.
# We wrap it as a `TightMatrix` class, which offers the following new functions:
# - `update_edge_tightness(self, edge_index: int, is_tight: bool)`
# - `is_tight(edge_index: int) -> bool`
# - `add_variable_with_tightness(self, edge_index: int, is_tight: bool)`
# - `add_tight_variable(self, edge_index: int)`
#
# By using `TightMatrix`, we assume edges by default are loose.
# Thus, newly added variables do not automatically show up.
# You need to either use `update_edge_tightness` to modify the tightness of the edge, or use `add_tight_variable` to directly add the edge as tight edge.

# %%
matrix = mwpf.TightMatrix()
matrix.add_constraint(vertex_index=0, incident_edges=[1, 4, 6], parity=True)
matrix.add_constraint(1, [4, 9], parity=False)
matrix.add_constraint(2, [1, 9], parity=True)
matrix.show()
# Out:
# <div id="KRSLBBLXKMJYMONM" style="font-family: monospace; white-space: pre;">┌─┬───┐
# ┊ ┊ = ┊
# ╞═╪═══╡
# ┊0┊ 1 ┊
# ├─┼───┤
# ┊1┊   ┊
# ├─┼───┤
# ┊2┊ 1 ┊
# └─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[],"table":[[""," = "],["0"," 1 "],["1","   "],["2"," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("KRSLBBLXKMJYMONM");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('KRSLBBLXKMJYMONM');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#KRSLBBLXKMJYMONM", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('KRSLBBLXKMJYMONM');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# Since edges are loose by default, you will not see any variable columns in the parity matrix. To show some of the variables, we just need to set some of the edges to tight.

# %%
matrix.update_edge_tightness(4, True)
matrix.update_edge_tightness(9, True)
matrix.show()
# Out:
# <div id="OQKGHMLDSEYVLRZT" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬───┐
# ┊ ┊4┊9┊ = ┊
# ╞═╪═╪═╪═══╡
# ┊0┊1┊ ┊ 1 ┊
# ├─┼─┼─┼───┤
# ┊1┊1┊1┊   ┊
# ├─┼─┼─┼───┤
# ┊2┊ ┊1┊ 1 ┊
# └─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[4,9],"table":[["","4","9"," = "],["0","1"," "," 1 "],["1","1","1","   "],["2"," ","1"," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("OQKGHMLDSEYVLRZT");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('OQKGHMLDSEYVLRZT');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#OQKGHMLDSEYVLRZT", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('OQKGHMLDSEYVLRZT');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# Of course, you can set an edge back to loose state.

# %%
matrix.update_edge_tightness(9, False)
matrix.show()
# Out:
# <div id="KIATSTKAJXTJGSJE" style="font-family: monospace; white-space: pre;">┌─┬─┬───┐
# ┊ ┊4┊ = ┊
# ╞═╪═╪═══╡
# ┊0┊1┊ 1 ┊
# ├─┼─┼───┤
# ┊1┊1┊   ┊
# ├─┼─┼───┤
# ┊2┊ ┊ 1 ┊
# └─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[4],"table":[["","4"," = "],["0","1"," 1 "],["1","1","   "],["2"," "," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("KIATSTKAJXTJGSJE");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('KIATSTKAJXTJGSJE');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#KIATSTKAJXTJGSJE", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('KIATSTKAJXTJGSJE');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# ## TailMatrix
#
# Tail matrix allows us to put some of the edges towards the end of the matrix.
# This is useful in the MWPF algorithm where we want the hair $\delta(S)$ of a non-zero dual variable $y_S > 0$ to be mostly to the right side so that it is isolated from the other dual variables.
# Built upon `TightMatrix`, the `TailMatrix` also default the edges to be loose, and thus we will not see anything below.

# %%
matrix = mwpf.TailMatrix()
matrix.add_constraint(vertex_index=0, incident_edges=[1, 4, 6], parity=True)
matrix.add_constraint(1, [4, 9], parity=False)
matrix.add_constraint(2, [1, 9], parity=True)
matrix.show()
# Out:
# <div id="NPNVTVQDJTHZELYD" style="font-family: monospace; white-space: pre;">┌─┬───┐
# ┊ ┊ = ┊
# ╞═╪═══╡
# ┊0┊ 1 ┊
# ├─┼───┤
# ┊1┊   ┊
# ├─┼───┤
# ┊2┊ 1 ┊
# └─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[],"table":[[""," = "],["0"," 1 "],["1","   "],["2"," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("NPNVTVQDJTHZELYD");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('NPNVTVQDJTHZELYD');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#NPNVTVQDJTHZELYD", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('NPNVTVQDJTHZELYD');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# Now we set all the edges to be tight.

# %%
for edge_index in [1, 4, 6, 9]:
    matrix.update_edge_tightness(edge_index, True)
matrix.show()
# Out:
# <div id="OMDOKFRZZWRSSTZO" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊1┊4┊6┊9┊ = ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊1┊1┊ ┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊ ┊1┊ ┊1┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊1┊ ┊ ┊1┊ 1 ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[1,4,6,9],"table":[["","1","4","6","9"," = "],["0","1","1","1"," "," 1 "],["1"," ","1"," ","1","   "],["2","1"," "," ","1"," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("OMDOKFRZZWRSSTZO");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('OMDOKFRZZWRSSTZO');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#OMDOKFRZZWRSSTZO", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('OMDOKFRZZWRSSTZO');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# We can set edges $\{1,6\}$ to be the tail of the matrix (towards the right side).
# Note that we cannot specify the order within the tail edges.
# The edges will be automatically ordered according to their variable index.
# (note: it is possible to force the order of the edges in Rust, by using some type like `Tail<CustomReorder<...>>` where `CustomReorder` will change the view of the matrix. However, our MWPF algorithm doesn't care much about the order so we do not use it for performance considerations)

# %%
matrix.set_tail_edges({6, 1})
assert matrix.get_tail_edges() == {1, 6}
matrix.show()
# Out:
# <div id="ZDPRPNMSSMTIYNWM" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊4┊9┊1┊6┊ = ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊ ┊1┊1┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊1┊1┊ ┊ ┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊ ┊1┊1┊ ┊ 1 ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[4,9,1,6],"table":[["","4","9","1","6"," = "],["0","1"," ","1","1"," 1 "],["1","1","1"," "," ","   "],["2"," ","1","1"," "," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("ZDPRPNMSSMTIYNWM");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('ZDPRPNMSSMTIYNWM');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#ZDPRPNMSSMTIYNWM", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('ZDPRPNMSSMTIYNWM');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# To revert the process, just set the tail edges to empty set.

# %%
matrix.set_tail_edges({})
matrix.show()
# Out:
# <div id="GQJPSZBEEFYGGSES" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊1┊4┊6┊9┊ = ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊1┊1┊ ┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊ ┊1┊ ┊1┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊1┊ ┊ ┊1┊ 1 ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[1,4,6,9],"table":[["","1","4","6","9"," = "],["0","1","1","1"," "," 1 "],["1"," ","1"," ","1","   "],["2","1"," "," ","1"," 1 "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("GQJPSZBEEFYGGSES");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('GQJPSZBEEFYGGSES');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#GQJPSZBEEFYGGSES", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('GQJPSZBEEFYGGSES');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# ## EchelonMatrix
#
# The reduced row Echelon form is a powerful tool to reason about the solution space among the tight edges.
# For example, if we have a graph that looks like this:

# %%
import math
vertex_num = 3
positions = [mwpf.VisualizePosition(i, j, 0) for (i, j) in [(0, 1-math.sqrt(3)), (-1, 1), (1, 1)]]
weighted_edges = [
    mwpf.HyperEdge({0, 2}, 1),
    mwpf.HyperEdge({0, 1}, 1),
    mwpf.HyperEdge({1, 2}, 1),
    mwpf.HyperEdge({0, 1, 2}, 1),
]
initializer = mwpf.SolverInitializer(vertex_num, weighted_edges)
solver = mwpf.Solver(initializer)
syndrome = mwpf.SyndromePattern({1})
solver.load_syndrome(syndrome)
visualizer = mwpf.Visualizer(positions=positions)
visualizer.snapshot("syndrome", solver)
# add dual variables
S0 = solver.get_node(0)  # S0 = ({1}, {})
S1 = solver.create_node({0,1,2}, {1,2,3})
solver.grow(mwpf.Rational(1))
visualizer.snapshot("grow 1", solver)
visualizer.show()
# Out:
# <div id="LMBAZSMHWAVOXHVY" style="width: auto; height: min(max(60vh, 400px), 100vw);"></div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const visualizer_data = '...';
#                 const override_config = {"full_screen":false};
#                 // get the current height and width of the div block
#                 const div = document.getElementById("LMBAZSMHWAVOXHVY");
#                 for (let i=0; i<10; ++i) {
#                     if (div.clientWidth != 0 && div.clientHeight != 0) break;
#                     await new Promise(resolve => setTimeout(resolve, 300));  // 300ms
#                     console.log(`waiting for div block $LMBAZSMHWAVOXHVY to be rendered [${i+1}/10]`);
#                 }
#                 const initial_aspect_ratio = div.clientWidth / div.clientHeight;
#                 if (override_config.initial_aspect_ratio == undefined) {
#                     if (!isNaN(initial_aspect_ratio)) {
#                         override_config.initial_aspect_ratio = initial_aspect_ratio;
#                         // save the data, in just a lot of them are being initialized at once and the aspect ratio is not correct
#                         window.loading_a_lot_hyperion_visual_initial_aspect_ratio = initial_aspect_ratio;
#                     } else if (window.loading_a_lot_hyperion_visual_initial_aspect_ratio != undefined) {
#                         override_config.initial_aspect_ratio = window.loading_a_lot_hyperion_visual_initial_aspect_ratio
#                     }
#                 }
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('LMBAZSMHWAVOXHVY');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.bind_to_div("#LMBAZSMHWAVOXHVY", visualizer_data, { ...window.hyperion_visual_2024_11_14_22_37_23.default_config(), ...override_config });
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('LMBAZSMHWAVOXHVY');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# The basic parity matrix of this state is:

# %%
matrix = mwpf.TightMatrix()
for edge_index in [0, 1, 2, 3]:
    matrix.add_tight_variable(edge_index)  # all edges are tight
matrix.add_constraint(vertex_index=0, incident_edges={1, 3, 0}, parity=False)
matrix.add_constraint(1, {1, 3, 2}, parity=True)
matrix.add_constraint(2, {2, 3, 0}, parity=False)
matrix.show()
# Out:
# <div id="VOXSWCZSIJFMKVJX" style="font-family: monospace; white-space: pre;">┌─┬─┬─┬─┬─┬───┐
# ┊ ┊0┊1┊2┊3┊ = ┊
# ╞═╪═╪═╪═╪═╪═══╡
# ┊0┊1┊1┊ ┊1┊   ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊1┊ ┊1┊1┊1┊ 1 ┊
# ├─┼─┼─┼─┼─┼───┤
# ┊2┊1┊ ┊1┊1┊   ┊
# └─┴─┴─┴─┴─┴───┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[0,1,2,3],"table":[["","0","1","2","3"," = "],["0","1","1"," ","1","   "],["1"," ","1","1","1"," 1 "],["2","1"," ","1","1","   "]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("VOXSWCZSIJFMKVJX");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('VOXSWCZSIJFMKVJX');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#VOXSWCZSIJFMKVJX", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('VOXSWCZSIJFMKVJX');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# The basic parity matrix does not give too much information about how to choose the edges: the choice of one edge will affect the possible choice of others.
# The reduced row Echelon form will help us explore the structure within this cluster.

# %%
matrix = mwpf.EchelonMatrix(matrix)
matrix.show()
# Out:
# <div id="DZTOLVFEGFPWWBCB" style="font-family: monospace; white-space: pre;">┌──┬─┬─┬─┬─┬───┬─┐
# ┊ E┊0┊1┊2┊3┊ = ┊▼┊
# ╞══╪═╪═╪═╪═╪═══╪═╡
# ┊ 0┊1┊ ┊1┊ ┊ 1 ┊0┊
# ├──┼─┼─┼─┼─┼───┼─┤
# ┊ 1┊ ┊1┊1┊ ┊   ┊1┊
# ├──┼─┼─┼─┼─┼───┼─┤
# ┊ 2┊ ┊ ┊ ┊1┊ 1 ┊3┊
# ├──┼─┼─┼─┼─┼───┼─┤
# ┊ ▶┊0┊1┊*┊2┊◀  ┊▲┊
# └──┴─┴─┴─┴─┴───┴─┘
# </div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const matrix_data = {"edges":[0,1,2,3],"hair_start_index":null,"is_echelon_form":true,"table":[["E","0","1","2","3"," = ","▼"],["0","1"," ","1"," "," 1 ","0"],["1"," ","1","1"," ","   ","1"],["2"," "," "," ","1"," 1 ","3"],[" ▶","0","1","*","2","◀  ","▲"]],"version":"0.1.4"};
#                 console.log(matrix_data);
#                 // get the current height and width of the div block
#                 const div = document.getElementById("DZTOLVFEGFPWWBCB");
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('DZTOLVFEGFPWWBCB');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.parity_matrix.bind_to_div("#DZTOLVFEGFPWWBCB", matrix_data);
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('DZTOLVFEGFPWWBCB');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# Given this reduced row Echelon form matrix, we are essentially transforming the decoding hypergraph into another form where the edges are still the same but the vertices are XOR'd with each other.
# The decoding hypergraph now looks like this:

# %%
weighted_edges = [
    mwpf.HyperEdge({0}, 1),
    mwpf.HyperEdge({1}, 1),
    mwpf.HyperEdge({0, 1}, 1),
    mwpf.HyperEdge({2}, 1),
]
initializer = mwpf.SolverInitializer(vertex_num, weighted_edges)
solver = mwpf.Solver(initializer)
syndrome = mwpf.SyndromePattern({0, 2})  # Attention! the vertices have a different syndrome, given by the RHS of the parity matrix above
solver.load_syndrome(syndrome)
visualizer = mwpf.Visualizer(positions=positions)
visualizer.snapshot("syndrome", solver)
# add dual variables; now the dual variables also changes.
solver.stop_all()
S0 = solver.create_node_hair_unchecked({1, 2, 3})  # original S0, hair = {1,2,3}
S1 = solver.create_node_hair_unchecked({0})  # original S1, hair = {0}
solver.grow(mwpf.Rational(1))
visualizer.snapshot("grow 1", solver)
visualizer.show()
# Out:
# <div id="LRSHILYZJVNZILQQ" style="width: auto; height: min(max(60vh, 400px), 100vw);"></div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const visualizer_data = '...';
#                 const override_config = {"full_screen":false};
#                 // get the current height and width of the div block
#                 const div = document.getElementById("LRSHILYZJVNZILQQ");
#                 for (let i=0; i<10; ++i) {
#                     if (div.clientWidth != 0 && div.clientHeight != 0) break;
#                     await new Promise(resolve => setTimeout(resolve, 300));  // 300ms
#                     console.log(`waiting for div block $LRSHILYZJVNZILQQ to be rendered [${i+1}/10]`);
#                 }
#                 const initial_aspect_ratio = div.clientWidth / div.clientHeight;
#                 if (override_config.initial_aspect_ratio == undefined) {
#                     if (!isNaN(initial_aspect_ratio)) {
#                         override_config.initial_aspect_ratio = initial_aspect_ratio;
#                         // save the data, in just a lot of them are being initialized at once and the aspect ratio is not correct
#                         window.loading_a_lot_hyperion_visual_initial_aspect_ratio = initial_aspect_ratio;
#                     } else if (window.loading_a_lot_hyperion_visual_initial_aspect_ratio != undefined) {
#                         override_config.initial_aspect_ratio = window.loading_a_lot_hyperion_visual_initial_aspect_ratio
#                     }
#                 }
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('LRSHILYZJVNZILQQ');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.bind_to_div("#LRSHILYZJVNZILQQ", visualizer_data, { ...window.hyperion_visual_2024_11_14_22_37_23.default_config(), ...override_config });
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('LRSHILYZJVNZILQQ');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# Now it becomes clear in the new decoding hypergraph that the blue dual variable (corresponds to the original S0) has a strange configuration: it could have grow on just one edge $\{3\}$ instead of on three edges $\{1,2,3\}$.
# This helps us make a decision that we should shrink $y_{S_0}$ and then increase the dual variable $S2 = (\{v'_{2}\}, \varnothing)$.

# %%
S2 = solver.create_node({2})
solver.set_grow_rate(S0, mwpf.Rational(-1))
solver.set_grow_rate(S1, mwpf.Rational(0))
solver.grow(mwpf.Rational(1))
visualizer.snapshot("shrink 1 + grow 1", solver)
visualizer.show()
# Out:
# <div id="HAPPRROTBOKWCWVE" style="width: auto; height: min(max(60vh, 400px), 100vw);"></div>
# <script>function hyperion_sleep(ms) {
#             return new Promise(resolve => setTimeout(resolve, ms))
#         }
#         async function on_hyperion_library_ready(func) {
#             // try it every 100ms, until 10s
#             for (let i = 0; i < 100; ++i) {
#                 if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                     break
#                 }
#                 if (i != 0 && i % 10 == 0) console.log(`window.hyperion_visual_2024_11_14_22_37_23 not ready, tried ${i} times`)
#                 await hyperion_sleep(100)
#             }
#             if (window.hyperion_visual_2024_11_14_22_37_23 != null) {
#                 func()
#             } else {
#                 throw new Error("window.hyperion_visual_2024_11_14_22_37_23 not found after 10s")
#             }
#         }
#             async function main() {
#                 const visualizer_data = '...';
#                 const override_config = {"full_screen":false};
#                 // get the current height and width of the div block
#                 const div = document.getElementById("HAPPRROTBOKWCWVE");
#                 for (let i=0; i<10; ++i) {
#                     if (div.clientWidth != 0 && div.clientHeight != 0) break;
#                     await new Promise(resolve => setTimeout(resolve, 300));  // 300ms
#                     console.log(`waiting for div block $HAPPRROTBOKWCWVE to be rendered [${i+1}/10]`);
#                 }
#                 const initial_aspect_ratio = div.clientWidth / div.clientHeight;
#                 if (override_config.initial_aspect_ratio == undefined) {
#                     if (!isNaN(initial_aspect_ratio)) {
#                         override_config.initial_aspect_ratio = initial_aspect_ratio;
#                         // save the data, in just a lot of them are being initialized at once and the aspect ratio is not correct
#                         window.loading_a_lot_hyperion_visual_initial_aspect_ratio = initial_aspect_ratio;
#                     } else if (window.loading_a_lot_hyperion_visual_initial_aspect_ratio != undefined) {
#                         override_config.initial_aspect_ratio = window.loading_a_lot_hyperion_visual_initial_aspect_ratio
#                     }
#                 }
#                 // bind the visualizer to the div block
#                 let app_currently_exist = false;
#                 async function create_app() {
#                     if (app_currently_exist) return;
#                     app_currently_exist = true;
#                     const script_dom = document.getElementById('HAPPRROTBOKWCWVE');
#                     const app = await window.hyperion_visual_2024_11_14_22_37_23.bind_to_div("#HAPPRROTBOKWCWVE", visualizer_data, { ...window.hyperion_visual_2024_11_14_22_37_23.default_config(), ...override_config });
#                     // observe the div block for removal
#                     new MutationObserver(function(mutations) {
#                         if(!document.body.contains(script_dom)) {
#                             app.unmount()
#                             this.disconnect()
#                             app_currently_exist = false
#                         }
#                     }).observe(script_dom.parentElement.parentElement.parentElement.parentElement.parentElement, { childList: true, subtree: true });
#                 }
#                 create_app()
#                 new MutationObserver(function(mutations) {
#                     const script_dom = document.getElementById('HAPPRROTBOKWCWVE');
#                     if(script_dom != undefined && script_dom.getAttribute('data-engine') == null) {
#                         create_app()
#                     }
#                 }).observe(document, { childList: true, subtree: true });
#             }
#             on_hyperion_library_ready(main)</script>

# %% [markdown]
# And then it becomes clear that we should choose edges $\{0, 3\}$ as the MWPF solution, whose primal summation is $\sum_{e\in E} x_e = 2$ and dual summation is also $\sum_{S\in \mathcal{O}} y_S = 2$.
